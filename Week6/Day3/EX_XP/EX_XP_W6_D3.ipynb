# %% [markdown]
# 🌟 Exercise 1 : Basic Usage of SciPy
# Instructions
# Import the SciPy library and explore its version.

# %%
import scipy
print(scipy.__version__)
print(dir(scipy))
# Out:
# 1.13.1
# ['LowLevelCallable', '__version__', 'cluster', 'constants', 'datasets', 'fft', 'fftpack', 'integrate', 'interpolate', 'io', 'linalg', 'misc', 'ndimage', 'odr', 'optimize', 'show_config', 'signal', 'sparse', 'spatial', 'special', 'stats', 'test']

# %% [markdown]
# 🌟 Exercise 2 : Descriptive Statistics
# Instructions
# Given a sample dataset, calculate the mean, median, variance, and standard deviation using SciPy.
# Sample dataset in code:
#
#
# data = [12, 15, 13, 12, 18, 20, 22, 21]

# %%
from scipy import stats

data = [12, 15, 13, 12, 18, 20, 22, 21]

mean = stats.tmean(data)

median = stats.scoreatpercentile(data, 50)

variance = stats.tvar(data)

std_dev = stats.tstd(data)

print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Variance: {variance}")
print(f"Standard Deviation: {std_dev}")
# Out:
# Mean: 16.625
# Median: 16.5
# Variance: 17.125
# Standard Deviation: 4.138236339311712

# %% [markdown]
# 🌟 Exercise 3 : Understanding Distributions
# Instructions
# Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10. Plot this distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mean = 50
std_dev = 10

x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

y = norm.pdf(x, mean, std_dev)

plt.plot(x, y, color='blue')

plt.title('Normal Distribution (mean=50, std=10)')
plt.xlabel('Value')
plt.ylabel('Probability Density')

plt.grid(True)
plt.show()

# %% [markdown]
# 🌟 Exercise 4 : T-Test Application
# Instructions
# Perform a T-test on two sets of randomly generated data. Hint: Use numpy.random.normal() to generate the datasets.

# %%
np.random.seed(0)
data_a = np.random.normal(loc=50, scale=5, size=100)

data_b = np.random.normal(loc=52, scale=5, size=100)

t_statistic, p_value = stats.ttest_ind(data_a, data_b)

print("T-statistic:", t_statistic)
print("P-value:", p_value)

plt.hist(data_a, bins=15, alpha=0.7, label='Data A')
plt.hist(data_b, bins=15, alpha=0.7, label='Data B')
plt.legend()
plt.title('Histogram of Data A and Data B')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
# Out:
# T-statistic: -2.908345837896863
# P-value: 0.00404840929812341

# %% [markdown]
# 🌟 Exercise 5 : Working with DataFrames
# Instructions
# Task: Import a dataset using Pandas and calculate descriptive statistics for a specific column using SciPy.
#
# Sample Dataset: Use any publicly available dataset (e.g., Iris dataset).
#
# Code Example:
#
#
#
# import pandas as pd
#
# df = pd.read_csv('path_to_iris_dataset.csv')
#
# # complete your code here

# %%
import pandas as pd

df = pd.read_csv('/content/iris_datset.csv')

df.head()

df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

sepal_length_stats = df['sepal_length'].describe()

sepal_length_stats
# Out:
# count    149.000000
# mean       5.848322
# std        0.828594
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %% [markdown]
# 🌟 Exercise 6 : Advanced Statistical Functions
# Instructions
# Task: Explore one advanced statistical function in SciPy and demonstrate its use with an example.
#
# Sample Task: Calculate kurtosis and skewness of a dataset.
#
# Code Example:
#
#
#
# data = np.random.normal(0, 1, 1000)
#
# # complete your code here

# %%
data = np.random.normal(0, 1, 1000)
# complete your code here

skewness = stats.skew(data)
kurtosis = stats.kurtosis(data)

print(f"Skewness: {skewness}")
print(f"Kurtosis: {kurtosis}")
# Out:
# Skewness: 0.011362317926249832
# Kurtosis: 0.0962426455486689
